# %%
from pyspark.sql.functions import col, avg, when,count
data = [
(101, "Arjun Kumar", "Python", 86, 92),
(102, "Neha Gupta", "Python", 74, 80),
(103, "Rahul Nair", "Data Engineering", 88, 85),
(104, "Priya Sharma", "AI", 91, 95),
(105, "Siddharth Rao", "Data Engineering", 67, 72),
(106, "Ayesha Khan", "AI", 79, 88),
(107, "Kavya Reddy", "Python", 94, 96),
(108, "Manish Yadav", "Data Engineering", 58, 69),
(109, "Divya Menon", "AI", 83, 90),
(110, "Farhan Ali", "Python", 62, 75)
]
columns = ["student_id", "student_name", "course", "marks", "attendance"]
df = spark.createDataFrame(data, columns)
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>student_id</th><th>student_name</th><th>course</th><th>marks</th><th>attendance</th></tr></thead><tbody><tr><td>101</td><td>Arjun Kumar</td><td>Python</td><td>86</td><td>92</td></tr><tr><td>102</td><td>Neha Gupta</td><td>Python</td><td>74</td><td>80</td></tr><tr><td>103</td><td>Rahul Nair</td><td>Data Engineering</td><td>88</td><td>85</td></tr><tr><td>104</td><td>Priya Sharma</td><td>AI</td><td>91</td><td>95</td></tr><tr><td>105</td><td>Siddharth Rao</td><td>Data Engineering</td><td>67</td><td>72</td></tr><tr><td>106</td><td>Ayesha Khan</td><td>AI</td><td>79</td><td>88</td></tr><tr><td>107</td><td>Kavya Reddy</td><td>Python</td><td>94</td><td>96</td></tr><tr><td>108</td><td>Manish Yadav</td><td>Data Engineering</td><td>58</td><td>69</td></tr><tr><td>109</td><td>Divya Menon</td><td>AI</td><td>83</td><td>90</td></tr><tr><td>110</td><td>Farhan Ali</td><td>Python</td><td>62</td><td>75</td></tr></tbody></table></div>

# %%
df=df.withColumn("Grade",
              when(col("marks")>=90,"A")
              .when(col("marks")>=75,"B")
              .when(col("marks")>=60,"C")
              .otherwise("Needs Improvement"))
df.show()
# Out:
# +----------+-------------+----------------+-----+----------+--------------------+-----------------+
# |student_id| student_name|          course|marks|attendance|certification_status|            Grade|
# +----------+-------------+----------------+-----+----------+--------------------+-----------------+
# |       101|  Arjun Kumar|          Python|   86|        92|            Eligible|                B|
# |       102|   Neha Gupta|          Python|   74|        80|        Not Eligible|                C|
# |       103|   Rahul Nair|Data Engineering|   88|        85|            Eligible|                B|
# |       104| Priya Sharma|              AI|   91|        95|            Eligible|                A|
# |       105|Siddharth Rao|Data Engineering|   67|        72|        Not Eligible|                C|
# |       106|  Ayesha Khan|              AI|   79|        88|            Eligible|                B|
# |       107|  Kavya Reddy|          Python|   94|        96|            Eligible|                A|
# |       108| Manish Yadav|Data Engineering|   58|        69|        Not Eligible|Needs Improvement|
# |       109|  Divya Menon|              AI|   83|        90|            Eligible|                B|
# |       110|   Farhan Ali|          Python|   62|        75|        Not Eligible|                C|
# +----------+-------------+----------------+-----+----------+--------------------+-----------------+

# %%
df = df.withColumn(
    "certification_status",
    when((col("marks") >= 75) & (col("attendance") >= 80), "Eligible")
    .otherwise("Not Eligible")
)
df.show()
# Out:
# +----------+-------------+----------------+-----+----------+--------------------+
# |student_id| student_name|          course|marks|attendance|certification_status|
# +----------+-------------+----------------+-----+----------+--------------------+
# |       101|  Arjun Kumar|          Python|   86|        92|            Eligible|
# |       102|   Neha Gupta|          Python|   74|        80|        Not Eligible|
# |       103|   Rahul Nair|Data Engineering|   88|        85|            Eligible|
# |       104| Priya Sharma|              AI|   91|        95|            Eligible|
# |       105|Siddharth Rao|Data Engineering|   67|        72|        Not Eligible|
# |       106|  Ayesha Khan|              AI|   79|        88|            Eligible|
# |       107|  Kavya Reddy|          Python|   94|        96|            Eligible|
# |       108| Manish Yadav|Data Engineering|   58|        69|        Not Eligible|
# |       109|  Divya Menon|              AI|   83|        90|            Eligible|
# |       110|   Farhan Ali|          Python|   62|        75|        Not Eligible|
# +----------+-------------+----------------+-----+----------+--------------------+

# %%
df.groupBy("course").avg("marks").show()
# Out:
# +----------------+-----------------+
# |          course|       avg(marks)|
# +----------------+-----------------+
# |          Python|             79.0|
# |Data Engineering|             71.0|
# |              AI|84.33333333333333|
# +----------------+-----------------+

# %%
from pyspark.sql.functions import count
eligible_count = df.filter(col("certification_status") == "Eligible") \
                   .groupBy("course") \
                   .agg(count("*").alias("eligible_students"))

display(eligible_count)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>course</th><th>eligible_students</th></tr></thead><tbody><tr><td>Python</td><td>2</td></tr><tr><td>Data Engineering</td><td>1</td></tr><tr><td>AI</td><td>3</td></tr></tbody></table></div>
