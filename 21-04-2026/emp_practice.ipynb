# %%
from pyspark.sql import SparkSession
spark=SparkSession.builder.appName("Practice").getOrCreate()
print("spark is created")
# Out:
# spark is created

# %%
data = [(1, "Rahul", "IT", 70000, "2024-01-10"),
 (2, "Sneha", "HR", 60000, "2024-02-15"),
(3, "Arjun", "IT", 75000, "2024-03-01"),
(4, "Priya", "Finance", 80000, "2024-01-25"),
(5, "Karan", None, 50000, "2024-02-20")

]
columns = ["emp_id", "name", "department", "salary", "joining_date"]
df = spark.createDataFrame(data, columns)

df.show()
# Out:
# +------+-----+----------+------+------------+
# |emp_id| name|department|salary|joining_date|
# +------+-----+----------+------+------------+
# |     1|Rahul|        IT| 70000|  2024-01-10|
# |     2|Sneha|        HR| 60000|  2024-02-15|
# |     3|Arjun|        IT| 75000|  2024-03-01|
# |     4|Priya|   Finance| 80000|  2024-01-25|
# |     5|Karan|      NULL| 50000|  2024-02-20|
# +------+-----+----------+------+------------+

# %%
df.show()
df.printSchema()
df.columns
df.count()
# Out:
# +------+-----+----------+------+------------+
# |emp_id| name|department|salary|joining_date|
# +------+-----+----------+------+------------+
# |     1|Rahul|        IT| 70000|  2024-01-10|
# |     2|Sneha|        HR| 60000|  2024-02-15|
# |     3|Arjun|        IT| 75000|  2024-03-01|
# |     4|Priya|   Finance| 80000|  2024-01-25|
# |     5|Karan|      NULL| 50000|  2024-02-20|
# +------+-----+----------+------+------------+
#
# root
#  |-- emp_id: long (nullable = true)
#  |-- name: string (nullable = true)
#  |-- department: string (nullable = true)
#  |-- salary: long (nullable = true)
#  |-- joining_date: string (nullable = true)
# 5

# %%
df.show(2)
df.show(4)
# Out:
# +------+-----+----------+------+------------+
# |emp_id| name|department|salary|joining_date|
# +------+-----+----------+------+------------+
# |     1|Rahul|        IT| 70000|  2024-01-10|
# |     2|Sneha|        HR| 60000|  2024-02-15|
# +------+-----+----------+------+------------+
# only showing top 2 rows
# +------+-----+----------+------+------------+
# |emp_id| name|department|salary|joining_date|
# +------+-----+----------+------+------------+
# |     1|Rahul|        IT| 70000|  2024-01-10|
# |     2|Sneha|        HR| 60000|  2024-02-15|
# |     3|Arjun|        IT| 75000|  2024-03-01|
# |     4|Priya|   Finance| 80000|  2024-01-25|
# +------+-----+----------+------+------------+
# only showing top 4 rows

# %%
df_renamed=df.withColumnRenamed("salary","emp_salary")
df_renamed.show()
#df.filter((df.salary>60000)&(df.department=="IT")).show()
# Out:
# +------+-----+----------+----------+------------+
# |emp_id| name|department|emp_salary|joining_date|
# +------+-----+----------+----------+------------+
# |     1|Rahul|        IT|     70000|  2024-01-10|
# |     2|Sneha|        HR|     60000|  2024-02-15|
# |     3|Arjun|        IT|     75000|  2024-03-01|
# |     4|Priya|   Finance|     80000|  2024-01-25|
# |     5|Karan|      NULL|     50000|  2024-02-20|
# +------+-----+----------+----------+------------+

# %%
df.filter(df.department=="IT").show()
# Out:
# +------+-----+----------+------+------------+
# |emp_id| name|department|salary|joining_date|
# +------+-----+----------+------+------------+
# |     1|Rahul|        IT| 70000|  2024-01-10|
# |     3|Arjun|        IT| 75000|  2024-03-01|
# +------+-----+----------+------+------------+

# %%
df.filter((df.salary>60000)&(df.department=="IT")).show()
# Out:
# +------+-----+----------+------+------------+
# |emp_id| name|department|salary|joining_date|
# +------+-----+----------+------+------------+
# |     1|Rahul|        IT| 70000|  2024-01-10|
# |     3|Arjun|        IT| 75000|  2024-03-01|
# +------+-----+----------+------+------------+

# %%
df.drop("joining_date").show()
# Out:
# +------+-----+----------+------+
# |emp_id| name|department|salary|
# +------+-----+----------+------+
# |     1|Rahul|        IT| 70000|
# |     2|Sneha|        HR| 60000|
# |     3|Arjun|        IT| 75000|
# |     4|Priya|   Finance| 80000|
# |     5|Karan|      NULL| 50000|
# +------+-----+----------+------+

# %%
from pyspark.sql.functions import sum, avg, max, min
df.select(sum("salary").alias("total_salary"),
          avg("salary").alias("average_salary"),
          max("salary").alias("max_salary"),
          (min("salary").alias("min_salary"))
          ).show()
# Out:
# +------------+--------------+----------+----------+
# |total_salary|average_salary|max_salary|min_salary|
# +------------+--------------+----------+----------+
# |      335000|       67000.0|     80000|     50000|
# +------------+--------------+----------+----------+

# %%
dept_data = [
("IT", "Bangalore"),
("HR", "Mumbai"),
("Finance", "Delhi")
]
dept_columns = ["department", "location"]
dept_df = spark.createDataFrame(dept_data, dept_columns)
dept_df.show()
# Out:
# +----------+---------+
# |department| location|
# +----------+---------+
# |        IT|Bangalore|
# |        HR|   Mumbai|
# |   Finance|    Delhi|
# +----------+---------+

# %%
df.join(dept_df, on="department", how="inner").show()
# Out:
# +----------+------+-----+------+------------+---------+
# |department|emp_id| name|salary|joining_date| location|
# +----------+------+-----+------+------------+---------+
# |   Finance|     4|Priya| 80000|  2024-01-25|    Delhi|
# |        HR|     2|Sneha| 60000|  2024-02-15|   Mumbai|
# |        IT|     1|Rahul| 70000|  2024-01-10|Bangalore|
# |        IT|     3|Arjun| 75000|  2024-03-01|Bangalore|
# +----------+------+-----+------+------------+---------+

# %%
df.join(dept_df, on="department", how="left").show()
# Out:
# +----------+------+-----+------+------------+---------+
# |department|emp_id| name|salary|joining_date| location|
# +----------+------+-----+------+------------+---------+
# |        HR|     2|Sneha| 60000|  2024-02-15|   Mumbai|
# |        IT|     1|Rahul| 70000|  2024-01-10|Bangalore|
# |      NULL|     5|Karan| 50000|  2024-02-20|     NULL|
# |   Finance|     4|Priya| 80000|  2024-01-25|    Delhi|
# |        IT|     3|Arjun| 75000|  2024-03-01|Bangalore|
# +----------+------+-----+------+------------+---------+

# %%
df.join(dept_df, on="department", how="right").show()
# Out:
# +----------+------+-----+------+------------+---------+
# |department|emp_id| name|salary|joining_date| location|
# +----------+------+-----+------+------------+---------+
# |        IT|     3|Arjun| 75000|  2024-03-01|Bangalore|
# |        IT|     1|Rahul| 70000|  2024-01-10|Bangalore|
# |        HR|     2|Sneha| 60000|  2024-02-15|   Mumbai|
# |   Finance|     4|Priya| 80000|  2024-01-25|    Delhi|
# +----------+------+-----+------+------------+---------+

# %%
df.withColumn("bonus",df.salary*0.10).show()
# Out:
# +------+-----+----------+------+------------+------+
# |emp_id| name|department|salary|joining_date| bonus|
# +------+-----+----------+------+------------+------+
# |     1|Rahul|        IT| 70000|  2024-01-10|7000.0|
# |     2|Sneha|        HR| 60000|  2024-02-15|6000.0|
# |     3|Arjun|        IT| 75000|  2024-03-01|7500.0|
# |     4|Priya|   Finance| 80000|  2024-01-25|8000.0|
# |     5|Karan|      NULL| 50000|  2024-02-20|5000.0|
# +------+-----+----------+------+------------+------+

# %%
from pyspark.sql.functions import col
df.filter(col("department").isNull()).show()
# Out:
# +------+-----+----------+------+------------+
# |emp_id| name|department|salary|joining_date|
# +------+-----+----------+------+------------+
# |     5|Karan|      NULL| 50000|  2024-02-20|
# +------+-----+----------+------+------------+

# %%
df.na.fill({"department":"Unknown"}).show()
# Out:
# +------+-----+----------+------+------------+
# |emp_id| name|department|salary|joining_date|
# +------+-----+----------+------+------------+
# |     1|Rahul|        IT| 70000|  2024-01-10|
# |     2|Sneha|        HR| 60000|  2024-02-15|
# |     3|Arjun|        IT| 75000|  2024-03-01|
# |     4|Priya|   Finance| 80000|  2024-01-25|
# |     5|Karan|   Unknown| 50000|  2024-02-20|
# +------+-----+----------+------+------------+

# %%
df.na.drop().show()
# Out:
# +------+-----+----------+------+------------+
# |emp_id| name|department|salary|joining_date|
# +------+-----+----------+------+------------+
# |     1|Rahul|        IT| 70000|  2024-01-10|
# |     2|Sneha|        HR| 60000|  2024-02-15|
# |     3|Arjun|        IT| 75000|  2024-03-01|
# |     4|Priya|   Finance| 80000|  2024-01-25|
# +------+-----+----------+------+------------+

# %%
from pyspark.sql.functions import upper,lower,length
df.select("name",
          upper("name").alias("upper_name"),
          lower("name").alias("lower_name"),
          length("name").alias("name_length")
          ).show()
# Out:
# +-----+----------+----------+-----------+
# | name|upper_name|lower_name|name_length|
# +-----+----------+----------+-----------+
# |Rahul|     RAHUL|     rahul|          5|
# |Sneha|     SNEHA|     sneha|          5|
# |Arjun|     ARJUN|     arjun|          5|
# |Priya|     PRIYA|     priya|          5|
# |Karan|     KARAN|     karan|          5|
# +-----+----------+----------+-----------+

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-09ee157f-8e1c-42cf-a6ab-487c1a57cb8f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-09ee157f-8e1c-42cf-a6ab-487c1a57cb8f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = spark.read.csv("employees.csv",header=True,inferSchema=True)
df.show()
# Out:
# +------+-----+----------+------+------------+
# |emp_id| name|department|salary|joining_date|
# +------+-----+----------+------+------------+
# |     1|Rahul|        IT| 70000|  2023-01-10|
# |     2|Sneha|        HR| 60000|  2022-11-15|
# |     3|Arjun|        IT| 75000|  2023-03-01|
# |     4|Priya|   Finance| 80000|  2022-12-20|
# |     5|Karan|        IT| 50000|  2023-02-05|
# |     6|Meera|      NULL| 72000|  2023-04-10|
# |     7| Amit|        HR| 58000|  2023-01-18|
# +------+-----+----------+------+------------+

# %%
df = spark.read.csv("departments.csv",header=True,inferSchema=True)
df.show()
# Out:
# +----------+---------+
# |department| location|
# +----------+---------+
# |        IT|Bangalore|
# |        HR|   Mumbai|
# |   Finance|    Delhi|
# +----------+---------+

# %%
df = spark.read.csv("sales.csv",header=True,inferSchema=True)
df.show()
# Out:
# +-------+------+--------+------+
# |sale_id|emp_id| product|amount|
# +-------+------+--------+------+
# |      1|     1|  Laptop| 75000|
# |      2|     2|   Mouse|  1500|
# |      3|     3|Keyboard|  3000|
# |      4|     1| Monitor| 12000|
# |      5|     4|  Laptop| 75000|
# |      6|     3|   Mouse|  1000|
# |      7|     5|Keyboard|  1500|
# |      8|     1|  Laptop| 75000|
# +-------+------+--------+------+

# %%
df = spark.read.csv("employees_nested.json",header=True,inferSchema=True)
df.show()
# Out:
# +--------------------+
# |                   [|
# +--------------------+
# |                   {|
# |          "emp_id":1|
# |      "name":"Rahul"|
# |   "address":{"ci...|
# |   "skills":["Pyt...|
# |                   }|
# |                   {|
# |          "emp_id":2|
# |      "name":"Sneha"|
# |   "address":{"ci...|
# |      "skills":["HR"|
# |                   }|
# |                   {|
# |          "emp_id":3|
# |      "name":"Arjun"|
# |   "address":{"ci...|
# |   "skills":["PyS...|
# |                   }|
# |                   ]|
# +--------------------+

# %%
#employees_df = spark.read.csv("employees.csv",header=True,inferSchema=True)
employees_df.show(5)
# Out:
# +------+-----+----------+------+------------+
# |emp_id| name|department|salary|joining_date|
# +------+-----+----------+------+------------+
# |     1|Rahul|        IT| 70000|  2023-01-10|
# |     2|Sneha|        HR| 60000|  2022-11-15|
# |     3|Arjun|        IT| 75000|  2023-03-01|
# |     4|Priya|   Finance| 80000|  2022-12-20|
# |     5|Karan|        IT| 50000|  2023-02-05|
# +------+-----+----------+------+------------+
# only showing top 5 rows

# %%
employees_df.count()
# Out:
# 7

# %%
employees_df.columns
# Out:
# ['emp_id', 'name', 'department', 'salary', 'joining_date']

# %%
employees_df.show(3)
# Out:
# +------+-----+----------+------+------------+
# |emp_id| name|department|salary|joining_date|
# +------+-----+----------+------+------------+
# |     1|Rahul|        IT| 70000|  2023-01-10|
# |     2|Sneha|        HR| 60000|  2022-11-15|
# |     3|Arjun|        IT| 75000|  2023-03-01|
# +------+-----+----------+------+------------+
# only showing top 3 rows

# %%
employees_df.select("name","salary").show()
# Out:
# +-----+------+
# | name|salary|
# +-----+------+
# |Rahul| 70000|
# |Sneha| 60000|
# |Arjun| 75000|
# |Priya| 80000|
# |Karan| 50000|
# |Meera| 72000|
# | Amit| 58000|
# +-----+------+

# %%
employees_df_rename=employees_df.withColumnRenamed("salary","emp_salary")
employees_df_rename.show()
# Out:
# +------+-----+----------+----------+------------+
# |emp_id| name|department|emp_salary|joining_date|
# +------+-----+----------+----------+------------+
# |     1|Rahul|        IT|     70000|  2023-01-10|
# |     2|Sneha|        HR|     60000|  2022-11-15|
# |     3|Arjun|        IT|     75000|  2023-03-01|
# |     4|Priya|   Finance|     80000|  2022-12-20|
# |     5|Karan|        IT|     50000|  2023-02-05|
# |     6|Meera|      NULL|     72000|  2023-04-10|
# |     7| Amit|        HR|     58000|  2023-01-18|
# +------+-----+----------+----------+------------+

# %%
employees_df.filter(employees_df.joining_date>"2023-01-01").show()
# Out:
# +------+-----+----------+------+------------+
# |emp_id| name|department|salary|joining_date|
# +------+-----+----------+------+------------+
# |     1|Rahul|        IT| 70000|  2023-01-10|
# |     3|Arjun|        IT| 75000|  2023-03-01|
# |     5|Karan|        IT| 50000|  2023-02-05|
# |     6|Meera|      NULL| 72000|  2023-04-10|
# |     7| Amit|        HR| 58000|  2023-01-18|
# +------+-----+----------+------+------------+

# %%
employees_df.filter(employees_df.salary>65000).show()
# Out:
# +------+-----+----------+------+------------+
# |emp_id| name|department|salary|joining_date|
# +------+-----+----------+------+------------+
# |     1|Rahul|        IT| 70000|  2023-01-10|
# |     3|Arjun|        IT| 75000|  2023-03-01|
# |     4|Priya|   Finance| 80000|  2022-12-20|
# |     6|Meera|      NULL| 72000|  2023-04-10|
# +------+-----+----------+------+------------+

# %%
employees_df.filter(employees_df.department=="IT").show()
# Out:
# +------+-----+----------+------+------------+
# |emp_id| name|department|salary|joining_date|
# +------+-----+----------+------+------------+
# |     1|Rahul|        IT| 70000|  2023-01-10|
# |     3|Arjun|        IT| 75000|  2023-03-01|
# |     5|Karan|        IT| 50000|  2023-02-05|
# +------+-----+----------+------+------------+

# %%
employees_df.filter((employees_df.department=="IT")&(employees_df.salary>70000)).show()
# Out:
# +------+-----+----------+------+------------+
# |emp_id| name|department|salary|joining_date|
# +------+-----+----------+------+------------+
# |     3|Arjun|        IT| 75000|  2023-03-01|
# +------+-----+----------+------+------------+

# %%
employees_df.drop("joining_date").show()
# Out:
# +------+-----+----------+------+
# |emp_id| name|department|salary|
# +------+-----+----------+------+
# |     1|Rahul|        IT| 70000|
# |     2|Sneha|        HR| 60000|
# |     3|Arjun|        IT| 75000|
# |     4|Priya|   Finance| 80000|
# |     5|Karan|        IT| 50000|
# |     6|Meera|      NULL| 72000|
# |     7| Amit|        HR| 58000|
# +------+-----+----------+------+

# %%
employees_df.orderBy(employees_df.salary).show()
# Out:
# +------+-----+----------+------+------------+
# |emp_id| name|department|salary|joining_date|
# +------+-----+----------+------+------------+
# |     5|Karan|        IT| 50000|  2023-02-05|
# |     7| Amit|        HR| 58000|  2023-01-18|
# |     2|Sneha|        HR| 60000|  2022-11-15|
# |     1|Rahul|        IT| 70000|  2023-01-10|
# |     6|Meera|      NULL| 72000|  2023-04-10|
# |     3|Arjun|        IT| 75000|  2023-03-01|
# |     4|Priya|   Finance| 80000|  2022-12-20|
# +------+-----+----------+------+------------+

# %%
employees_df.orderBy(employees_df.salary.desc()).show()
# Out:
# +------+-----+----------+------+------------+
# |emp_id| name|department|salary|joining_date|
# +------+-----+----------+------+------------+
# |     4|Priya|   Finance| 80000|  2022-12-20|
# |     3|Arjun|        IT| 75000|  2023-03-01|
# |     6|Meera|      NULL| 72000|  2023-04-10|
# |     1|Rahul|        IT| 70000|  2023-01-10|
# |     2|Sneha|        HR| 60000|  2022-11-15|
# |     7| Amit|        HR| 58000|  2023-01-18|
# |     5|Karan|        IT| 50000|  2023-02-05|
# +------+-----+----------+------+------------+
#
# +------+-----+----------+------+------------+
# |emp_id| name|department|salary|joining_date|
# +------+-----+----------+------+------------+
# |     1|Rahul|        IT| 70000|  2023-01-10|
# |     2|Sneha|        HR| 60000|  2022-11-15|
# |     3|Arjun|        IT| 75000|  2023-03-01|
# +------+-----+----------+------+------------+
# only showing top 3 rows

# %%
employees_df.orderBy(employees_df.salary.desc()).show(3)
# Out:
# +------+-----+----------+------+------------+
# |emp_id| name|department|salary|joining_date|
# +------+-----+----------+------+------------+
# |     4|Priya|   Finance| 80000|  2022-12-20|
# |     3|Arjun|        IT| 75000|  2023-03-01|
# |     6|Meera|      NULL| 72000|  2023-04-10|
# +------+-----+----------+------+------------+
# only showing top 3 rows

# %%
from pyspark.sql.functions import sum, avg, max, min
employees_df.select(sum("salary").alias("total_salary"),
avg("salary").alias("average_salary"),
max("salary").alias("highest_salary"),
min("salary").alias("lowest_salary")).show()
# Out:
# +------------+-----------------+--------------+-------------+
# |total_salary|   average_salary|highest_salary|lowest_salary|
# +------------+-----------------+--------------+-------------+
# |      465000|66428.57142857143|         80000|        50000|
# +------------+-----------------+--------------+-------------+

# %%
employees_df.groupBy("department").count().show()
# Out:
# +----------+-----+
# |department|count|
# +----------+-----+
# |        HR|    2|
# |      NULL|    1|
# |   Finance|    1|
# |        IT|    3|
# +----------+-----+

# %%
from pyspark.sql.functions import avg
employees_df.groupBy("department").avg("salary").show()
# Out:
# +----------+-----------+
# |department|avg(salary)|
# +----------+-----------+
# |        HR|    59000.0|
# |      NULL|    72000.0|
# |   Finance|    80000.0|
# |        IT|    65000.0|
# +----------+-----------+

# %%
from pyspark.sql.functions import sum
employees_df.groupBy("department").sum("salary").show()
# Out:
# +----------+-----------+
# |department|sum(salary)|
# +----------+-----------+
# |        HR|     118000|
# |      NULL|      72000|
# |   Finance|      80000|
# |        IT|     195000|
# +----------+-----------+

# %%
employees_df.join(dept_df, on="department", how="inner").show()
# Out:
# +----------+------+-----+------+------------+---------+
# |department|emp_id| name|salary|joining_date| location|
# +----------+------+-----+------+------------+---------+
# |        IT|     5|Karan| 50000|  2023-02-05|Bangalore|
# |        IT|     3|Arjun| 75000|  2023-03-01|Bangalore|
# |        IT|     1|Rahul| 70000|  2023-01-10|Bangalore|
# |        HR|     7| Amit| 58000|  2023-01-18|   Mumbai|
# |        HR|     2|Sneha| 60000|  2022-11-15|   Mumbai|
# |   Finance|     4|Priya| 80000|  2022-12-20|    Delhi|
# +----------+------+-----+------+------------+---------+

# %%
employees_df.join(dept_df, on="department", how="left").show()
# Out:
# +----------+------+-----+------+------------+---------+
# |department|emp_id| name|salary|joining_date| location|
# +----------+------+-----+------+------------+---------+
# |        HR|     2|Sneha| 60000|  2022-11-15|   Mumbai|
# |        HR|     7| Amit| 58000|  2023-01-18|   Mumbai|
# |      NULL|     6|Meera| 72000|  2023-04-10|     NULL|
# |   Finance|     4|Priya| 80000|  2022-12-20|    Delhi|
# |        IT|     1|Rahul| 70000|  2023-01-10|Bangalore|
# |        IT|     3|Arjun| 75000|  2023-03-01|Bangalore|
# |        IT|     5|Karan| 50000|  2023-02-05|Bangalore|
# +----------+------+-----+------+------------+---------+

# %%
employees_df.join(dept_df, "department", "inner") \
      .select("name", "location").show()
# Out:
# +-----+---------+
# | name| location|
# +-----+---------+
# |Karan|Bangalore|
# |Arjun|Bangalore|
# |Rahul|Bangalore|
# | Amit|   Mumbai|
# |Sneha|   Mumbai|
# |Priya|    Delhi|
# +-----+---------+

# %%
employees_df.withColumn("bonus",employees_df.salary*0.10).show()
# Out:
# +------+-----+----------+------+------------+------+
# |emp_id| name|department|salary|joining_date| bonus|
# +------+-----+----------+------+------------+------+
# |     1|Rahul|        IT| 70000|  2023-01-10|7000.0|
# |     2|Sneha|        HR| 60000|  2022-11-15|6000.0|
# |     3|Arjun|        IT| 75000|  2023-03-01|7500.0|
# |     4|Priya|   Finance| 80000|  2022-12-20|8000.0|
# |     5|Karan|        IT| 50000|  2023-02-05|5000.0|
# |     6|Meera|      NULL| 72000|  2023-04-10|7200.0|
# |     7| Amit|        HR| 58000|  2023-01-18|5800.0|
# +------+-----+----------+------+------------+------+

# %%
from pyspark.sql.functions import lit
employees_df.withColumn("Company",lit("BotCampus")).show()
# Out:
# +------+-----+----------+------+------------+---------+
# |emp_id| name|department|salary|joining_date|  Company|
# +------+-----+----------+------+------------+---------+
# |     1|Rahul|        IT| 70000|  2023-01-10|BotCampus|
# |     2|Sneha|        HR| 60000|  2022-11-15|BotCampus|
# |     3|Arjun|        IT| 75000|  2023-03-01|BotCampus|
# |     4|Priya|   Finance| 80000|  2022-12-20|BotCampus|
# |     5|Karan|        IT| 50000|  2023-02-05|BotCampus|
# |     6|Meera|      NULL| 72000|  2023-04-10|BotCampus|
# |     7| Amit|        HR| 58000|  2023-01-18|BotCampus|
# +------+-----+----------+------+------------+---------+

# %%
from pyspark.sql.functions import col
employees_df.filter(col("department").isNull()).show()
# Out:
# +------+-----+----------+------+------------+
# |emp_id| name|department|salary|joining_date|
# +------+-----+----------+------+------------+
# |     6|Meera|      NULL| 72000|  2023-04-10|
# +------+-----+----------+------+------------+

# %%
employees_df.na.fill({"department":"Unknown"}).show()
# Out:
# +------+-----+----------+------+------------+
# |emp_id| name|department|salary|joining_date|
# +------+-----+----------+------+------------+
# |     1|Rahul|        IT| 70000|  2023-01-10|
# |     2|Sneha|        HR| 60000|  2022-11-15|
# |     3|Arjun|        IT| 75000|  2023-03-01|
# |     4|Priya|   Finance| 80000|  2022-12-20|
# |     5|Karan|        IT| 50000|  2023-02-05|
# |     6|Meera|   Unknown| 72000|  2023-04-10|
# |     7| Amit|        HR| 58000|  2023-01-18|
# +------+-----+----------+------+------------+

# %%
employees_df.na.drop().show()
# Out:
# +------+-----+----------+------+------------+
# |emp_id| name|department|salary|joining_date|
# +------+-----+----------+------+------------+
# |     1|Rahul|        IT| 70000|  2023-01-10|
# |     2|Sneha|        HR| 60000|  2022-11-15|
# |     3|Arjun|        IT| 75000|  2023-03-01|
# |     4|Priya|   Finance| 80000|  2022-12-20|
# |     5|Karan|        IT| 50000|  2023-02-05|
# |     7| Amit|        HR| 58000|  2023-01-18|
# +------+-----+----------+------+------------+

# %%
from pyspark.sql.functions import upper,length
employees_df.select(upper("name")).show()
employees_df.select(length("name")).show()
# Out:
# +-----------+
# |upper(name)|
# +-----------+
# |      RAHUL|
# |      SNEHA|
# |      ARJUN|
# |      PRIYA|
# |      KARAN|
# |      MEERA|
# |       AMIT|
# +-----------+
#
# +------------+
# |length(name)|
# +------------+
# |           5|
# |           5|
# |           5|
# |           5|
# |           5|
# |           5|
# |           4|
# +------------+

# %%
employees_df.withColumn("salary_in_lakhs", employees_df.salary / 100000).show()
# Out:
# +------+-----+----------+------+------------+---------------+
# |emp_id| name|department|salary|joining_date|salary_in_lakhs|
# +------+-----+----------+------+------------+---------------+
# |     1|Rahul|        IT| 70000|  2023-01-10|            0.7|
# |     2|Sneha|        HR| 60000|  2022-11-15|            0.6|
# |     3|Arjun|        IT| 75000|  2023-03-01|           0.75|
# |     4|Priya|   Finance| 80000|  2022-12-20|            0.8|
# |     5|Karan|        IT| 50000|  2023-02-05|            0.5|
# |     6|Meera|      NULL| 72000|  2023-04-10|           0.72|
# |     7| Amit|        HR| 58000|  2023-01-18|           0.58|
# +------+-----+----------+------+------------+---------------+
